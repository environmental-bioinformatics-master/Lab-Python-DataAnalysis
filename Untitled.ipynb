# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load in pandas data

# %%
 pd.read_csv('data/groundhog.csv')

# %% [markdown]
# ## What is a dataframe?
# A DataFrame is a data structure that can store a variety of data types (e.g. numeric (integers and floats), strings, objects, and more!) in a 2D structre (rows by columns). It is similar to a spreadsheet or an SQL table or the data.frame in R. A DataFrame always has an index (0-based). An index refers to the position of an element in the data structure.

# %%
pd.read_csv('data/groundhog.csv')
# Out:
#           Year Punxsutawney Phil  February Average Temperature  \
# 0         1886         No Record                           NaN
# 1         1887       Full Shadow                           NaN
# 2         1888       Full Shadow                           NaN
# 3         1889         No Record                           NaN
# 4         1890         No Shadow                           NaN
# 5         1891         No Record                           NaN
# 6         1892         No Record                           NaN
# 7         1893         No Record                           NaN
# 8         1894         No Record                           NaN
# 9         1895         No Record                         26.60
# 10        1896         No Record                         35.04
# 11        1897         No Record                         33.39
# 12        1898       Full Shadow                         35.37
# 13        1899         No Record                         25.50
# ...

# %%
ghog_df = pd.read_csv('data/groundhog.csv')

# %%
ghog_df.columns
# Out:
# Index(['Year', 'Punxsutawney Phil', 'February Average Temperature',
#        'February Average Temperature (Northeast)',
#        'February Average Temperature (Midwest)',
#        'February Average Temperature (Pennsylvania)',
#        'March Average Temperature', 'March Average Temperature (Northeast)',
#        'March Average Temperature (Midwest)',
#        'March Average Temperature (Pennsylvania)'],
#       dtype='object')

# %%
sns.violinplot(data=ghog_df, hue = 'Punxsutawney Phil', x = 'February Average Temperature', y='March Average Temperature')

# %% [markdown]
# There are many ways to summarize and access the data stored in DataFrames-- pandas has a variety of associated `attirbutes` and `methods`.
#
# An `attribute` is a value or characteristic that is associated with the data-- think of it as a variable that is stored within an object (dataframe in this case). A `method` is a set of instructions or functions associated with an object.
#
# To access an `attribute`, use the DataFrame object name followed by the attribute. Using the DataFrame `ghog_df` and attribute `columns`, to get an index of all the column names in the DataFrame can be accessed with `ghog_df.columns`.

# %%
ghog_df.columns
# Out:
# Index(['Year', 'Punxsutawney Phil', 'February Average Temperature',
#        'February Average Temperature (Northeast)',
#        'February Average Temperature (Midwest)',
#        'February Average Temperature (Pennsylvania)',
#        'March Average Temperature', 'March Average Temperature (Northeast)',
#        'March Average Temperature (Midwest)',
#        'March Average Temperature (Pennsylvania)'],
#       dtype='object')

# %%
ghog_df.index
# Out:
# RangeIndex(start=0, stop=132, step=1)

# %% [markdown]
# Methods are called in a similar fashion using the syntax `df_object.method()`-- but the paraentheses are required. As an example, `surveys_df.head()` gets the first few rows in the DataFrame `ghog_df` using the `head()` method. With a method, we can supply extra information in the parens to control behavior -- fo example: pass `n=100` to head to get more lines.

# %%
ghog_df.head()
# Out:
#    Year Punxsutawney Phil  February Average Temperature  \
# 0  1886         No Record                           NaN
# 1  1887       Full Shadow                           NaN
# 2  1888       Full Shadow                           NaN
# 3  1889         No Record                           NaN
# 4  1890         No Shadow                           NaN
#
#    February Average Temperature (Northeast)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    February Average Temperature (Midwest)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    February Average Temperature (Pennsylvania)  March Average Temperature  \
# ...

# %%
ghog_df.head(n=10)
# Out:
#    Year Punxsutawney Phil  February Average Temperature  \
# 0  1886         No Record                           NaN
# 1  1887       Full Shadow                           NaN
# 2  1888       Full Shadow                           NaN
# 3  1889         No Record                           NaN
# 4  1890         No Shadow                           NaN
# 5  1891         No Record                           NaN
# 6  1892         No Record                           NaN
# 7  1893         No Record                           NaN
# 8  1894         No Record                           NaN
# 9  1895         No Record                          26.6
#
#    February Average Temperature (Northeast)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# ...

# %%
ghog_df.mean()
# Out:
# February Average Temperature                   33.802846
# February Average Temperature (Northeast)       22.691870
# February Average Temperature (Midwest)         32.695935
# February Average Temperature (Pennsylvania)    26.522764
# March Average Temperature                      41.697398
# March Average Temperature (Northeast)          32.367480
# March Average Temperature (Midwest)            42.567480
# March Average Temperature (Pennsylvania)       35.908130
# dtype: float64

# %%
ghog_df.describe()
# Out:
#        February Average Temperature  February Average Temperature (Northeast)  \
# count                    123.000000                                123.000000
# mean                      33.802846                                 22.691870
# std                        3.269379                                  4.265619
# min                       25.230000                                 10.400000
# 25%                       31.785000                                 20.050000
# 50%                       33.690000                                 22.900000
# 75%                       36.005000                                 25.950000
# max                       41.410000                                 31.600000
#
#        February Average Temperature (Midwest)  \
# count                              123.000000
# mean                                32.695935
# std                                  4.843881
# min                                 20.300000
# ...

# %%
## Summary statistics

# %%
otu_df = pd.read_csv('data/Cariaco_OTU.csv')

# %%
otu_df = pd.read_csv('data/Cariaco_OTU.csv', index_col=0)

# %%
otu_df.columns
# Out:
# Index(['AB2a143A', 'AB2a143B', 'AB2a200A', 'AB2a200B', 'AB2a237A', 'AB2a237B',
#        'AB2a247A', 'AB2a247B', 'AB2a267A', 'AB2a267B', 'AB2a900A', 'AB2a900B',
#        'AB2b143A', 'AB2b143B', 'AB2b200A', 'AB2b200B', 'AB2b237A', 'AB2b237B',
#        'AB2b247A', 'AB2b247B', 'AB2b267A', 'AB2b267B', 'AB2b900A', 'AB2b900B',
#        'taxonomy', 'class'],
#       dtype='object')

# %%
otu_df.index
# Out:
# Index(['denovo231149', 'denovo348086', 'denovo302903', 'denovo104772',
#        'denovo309274', 'denovo26278', 'denovo290780', 'denovo118147',
#        'denovo258351', 'denovo408458',
#        ...
#        'denovo184679', 'denovo203484', 'denovo257738', 'denovo399540',
#        'denovo305250', 'denovo28042', 'denovo389492', 'denovo456367',
#        'denovo75288', 'denovo87700'],
#       dtype='object', name='#OTU ID', length=755)

# %%
otu_df.describe()
# Out:
#            AB2a143A      AB2a143B    AB2a200A      AB2a200B      AB2a237A  \
# count    755.000000    755.000000  755.000000    755.000000    755.000000
# mean     369.011921    423.406623    0.174834    386.060927    656.149669
# std     1789.066047   1778.876649    0.846996   1540.748560   3616.775853
# min        0.000000      0.000000    0.000000      0.000000      0.000000
# 25%        1.000000      0.000000    0.000000      0.000000     10.500000
# 50%       40.000000     13.000000    0.000000     13.000000     64.000000
# 75%      238.500000    216.500000    0.000000    147.500000    291.000000
# max    41541.000000  25922.000000    9.000000  18207.000000  71692.000000
#
#            AB2a237B      AB2a247A       AB2a247B      AB2a267A      AB2a267B  \
# count    755.000000    755.000000     755.000000    755.000000    755.000000
# mean     214.360265    645.923179     458.564238    309.561589    285.776159
# ...

# %%
otu_df['class']=otu_df.taxonomy.str.split(';').str[1]

# %%
otu_df.groupby('class').sum().T.plot(kind='bar', stacked=True)
